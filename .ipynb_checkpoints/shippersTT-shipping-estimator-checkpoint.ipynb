# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_squared_log_error

# %%
data = pd.read_csv('shippers_clearing_fees.csv')
data = pd.read_csv('clearing_fees_10000_ultra_optimized.csv')
data.head(5)
# Out:
#       category  weight    cost
# 0        shoes       3  257.34
# 1        shoes       4  287.12
# 2        other       2  130.58
# 3  electronics       3   97.78
# 4     clothing       3  153.87

# %%
data.shape
# Out:
# (10000, 3)

# %%
data.dtypes
# Out:
# category     object
# weight        int64
# cost        float64
# dtype: object

# %%
data_encoded = pd.get_dummies(data, drop_first=True)
corr_matrix = data_encoded.corr()
fig, ax = plt.subplots(figsize=(10,5))
ax = sns.heatmap(corr_matrix, annot=True, linewidth=0.5, fmt=" .2f", cmap="YlGnBu")

# %%
models = {'RandomForest': RandomForestRegressor(),
          'Linear Regression': LinearRegression(),
          'Lasso': Lasso(),
          'Gradient Boosting': GradientBoostingRegressor(),
          'Ridge': Ridge()
         }

# %%
def rmsle(y_true, y_pred):
    offset = abs(min(min(y_true), min(y_pred))) + 1 if min(min(y_true), min(y_pred)) <= 0 else 0

    y_true_shifted = y_true + offset
    y_pred_shifted = y_pred + offset

    return np.sqrt(mean_squared_log_error(y_true_shifted, y_pred_shifted))

def show_scores(models, X_train, X_test, y_train, y_test):
    model_scores={}
    for name, model in models.items():
        model.fit(X_train, y_train)
        preds = model.predict(X_test)
        scores = {
                  'MAE': mean_absolute_error(y_test, preds),
                  'RMSLE': rmsle(y_test, preds),
                  'MSE': mean_squared_error(y_test, preds),
                  'R^2': r2_score(y_test, preds)}
        model_scores[name] = scores
    return model_scores

# %%
X = data.drop(['cost'], axis=1)
X.head()
# Out:
#       category  weight
# 0        shoes       3
# 1        shoes       4
# 2        other       2
# 3  electronics       3
# 4     clothing       3

# %%
y = data['cost']
y
# Out:
# 0        257.34
# 1        287.12
# 2        130.58
# 3         97.78
# 4        153.87
#          ...
# 9995    2090.75
# 9996      36.30
# 9997     878.20
# 9998    1179.10
# 9999     215.09
# Name: cost, Length: 10000, dtype: float64

# %%
worded_features = ['category']
one_hot = OneHotEncoder()
transformer = ColumnTransformer([('one_hot',
                                   one_hot,
                                   worded_features)],
                                   remainder='passthrough')
transformed_X = transformer.fit_transform(X)
transformed_X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 20000 stored elements and shape (10000, 12)>

# %%
np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(transformed_X, y, test_size=0.20)
scores = show_scores(models, X_train, X_test, y_train, y_test)
mae_scores={}
for name in scores:
    print(name)
    print('MAE: ', scores[name]['MAE'])
    print('RMSLE: ', scores[name]['RMSLE'])
    print('MSE: ', scores[name]['MSE'])
    print('R^2: ', scores[name]['R^2'])
    print('\n')
    mae_scores[name] = scores[name]['MAE']
# Out:
# RandomForest
# MAE:  26.932699932037465
# RMSLE:  0.1269844190105755
# MSE:  1851.703401506077
# R^2:  0.9959965531880086
#
#
# Linear Regression
# MAE:  55.1785686776947
# RMSLE:  0.4455573698307649
# MSE:  5718.142638304094
# R^2:  0.9876371778022272
#
#
# Lasso
# MAE:  56.08945657774877
# RMSLE:  0.4431089153213503
# MSE:  5971.865373375445
# R^2:  0.9870886204717039
#
#
# Gradient Boosting
# MAE:  31.46681224736262
# RMSLE:  0.17546617634132033
# MSE:  2113.4556599705834
# R^2:  0.9954306357501355
#
#
# Ridge
# MAE:  55.27400962942216
# RMSLE:  0.44559643774058616
# MSE:  5724.832598835442
# R^2:  0.9876227138761255

# %%
mae_scores
# Out:
# {'RandomForest': 26.932699932037465,
#  'Linear Regression': 55.1785686776947,
#  'Lasso': 56.08945657774877,
#  'Gradient Boosting': 31.46681224736262,
#  'Ridge': 55.27400962942216}

# %%
comparison = pd.DataFrame(mae_scores, index=["Mean Absolute Error"])
comparison.plot.bar(width=2);
plt.title("Mean Absolute Scores for Models");

# %%
def show_tuned_scores(model, X_test, y_test, name):
    model_scores={}
    preds = model.predict(X_test)
    scores = {
                'MAE': mean_absolute_error(y_test, preds),
                'RMSLE': rmsle(y_test, preds),
                'MSE': mean_squared_error(y_test, preds),
                'R^2': r2_score(y_test, preds)}
    model_scores[name] = scores
    return model_scores

# %%
param_grid = {
    'alpha': np.logspace(-4, 1, 50)  # Try alpha from 0.0001 to 10
}

# %%
lass = GridSearchCV(
    estimator=Lasso(),
    param_grid=param_grid,
    cv=5,                
    scoring='neg_mean_absolute_error',
    n_jobs=-1
)

lass.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(), n_jobs=-1,
#              param_grid={'alpha': array([1.00000000e-04, 1.26485522e-04, 1.59985872e-04, 2.02358965e-04,
#        2.55954792e-04, 3.23745754e-04, 4.09491506e-04, 5.17947468e-04,
#        6.55128557e-04, 8.28642773e-04, 1.04811313e-03, 1.32571137e-03,
#        1.67683294e-03, 2.12095089e-03, 2.68269580e-03, 3.39322177e-03,
#        4.29193426e-03, 5.42867544e-03, 6.86648...
#        7.19685673e-02, 9.10298178e-02, 1.15139540e-01, 1.45634848e-01,
#        1.84206997e-01, 2.32995181e-01, 2.94705170e-01, 3.72759372e-01,
#        4.71486636e-01, 5.96362332e-01, 7.54312006e-01, 9.54095476e-01,
#        1.20679264e+00, 1.52641797e+00, 1.93069773e+00, 2.44205309e+00,
#        3.08884360e+00, 3.90693994e+00, 4.94171336e+00, 6.25055193e+00,
#        7.90604321e+00, 1.00000000e+01])},
#              scoring='neg_mean_absolute_error')

# %%
lass.best_params_
# Out:
# {'alpha': np.float64(0.2329951810515372)}

# %%
lass_scores = show_tuned_scores(lass, X_test, y_test, name='Tuned Lasso')
lass_scores
# Out:
# {'Tuned Lasso': {'MAE': 55.0894048042134,
#   'RMSLE': np.float64(0.4442024248873166),
#   'MSE': 5723.4261866955385,
#   'R^2': 0.9876257545878255}}

# %%
rf_params = {
    'n_estimators': [100, 150, 200, 250],   # Default is 100
    'max_depth': [None, 10, 20, 30],        # Default is None
    'min_samples_split': [2, 3, 4],         # Default is 2
    'min_samples_leaf': [1, 2],             # Default is 1
    'max_features': ['sqrt'],               # Default for regression is 'auto' which is sqrt(n_features)
    'bootstrap': [True]
}

# %%
np.random.seed(42)
rf = RandomizedSearchCV(
    RandomForestRegressor(random_state=42),
    param_distributions=rf_params,
    n_iter=30,                    # More iterations
    scoring='neg_mean_absolute_error',
    cv=5,
    verbose=1,
    n_jobs=-1,
    random_state=42
)
rf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#                    n_iter=30, n_jobs=-1,
#                    param_distributions={'bootstrap': [True],
#                                         'max_depth': [None, 10, 20, 30],
#                                         'max_features': ['sqrt'],
#                                         'min_samples_leaf': [1, 2],
#                                         'min_samples_split': [2, 3, 4],
#                                         'n_estimators': [100, 150, 200, 250]},
#                    random_state=42, scoring='neg_mean_absolute_error',
#                    verbose=1)

# %%
rf.best_params_
# Out:
# {'n_estimators': 150,
#  'min_samples_split': 4,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': None,
#  'bootstrap': True}

# %%
rf_scores = show_tuned_scores(rf, X_test, y_test, name='Tuned Random Forest')
rf_scores
# Out:
# {'Tuned Random Forest': {'MAE': 26.939573778039026,
#   'RMSLE': np.float64(0.1266172288091018),
#   'MSE': 1854.9122402835915,
#   'R^2': 0.9959896155675648}}

# %%
gb_params = {
    'n_estimators': np.arange(100, 501, 50),  
    'learning_rate': np.linspace(0.01, 0.1, 5),  
    'max_depth': np.arange(2, 6),  
    'subsample': np.linspace(0.6, 1.0, 5), 
    'min_samples_split': [2, 5, 10],  
    'min_samples_leaf': [1, 2, 4]
}

# %%
np.random.seed(42)
gb = RandomizedSearchCV(GradientBoostingRegressor(), gb_params, n_iter=10, cv=5)
gb.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#                    param_distributions={'learning_rate': array([0.01  , 0.0325, 0.055 , 0.0775, 0.1   ]),
#                                         'max_depth': array([2, 3, 4, 5]),
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': array([100, 150, 200, 250, 300, 350, 400, 450, 500]),
#                                         'subsample': array([0.6, 0.7, 0.8, 0.9, 1. ])})

# %%
gb.best_params_
# Out:
# {'subsample': np.float64(0.8),
#  'n_estimators': np.int64(400),
#  'min_samples_split': 10,
#  'min_samples_leaf': 2,
#  'max_depth': np.int64(5),
#  'learning_rate': np.float64(0.0325)}

# %%
gb_scores = show_tuned_scores(gb, X_test, y_test, name='Tuned Gradient Boosting')
gb_scores
# Out:
# {'Tuned Gradient Boosting': {'MAE': 27.164234838556528,
#   'RMSLE': np.float64(0.12502162179140439),
#   'MSE': 1852.9292238249168,
#   'R^2': 0.995993902917749}}

# %%
train_scores = show_tuned_scores(rf, X_train, y_train, name='RF Train Scores')
train_scores
# Out:
# {'RF Train Scores': {'MAE': 26.348708469565835,
#   'RMSLE': np.float64(0.11609897951767544),
#   'MSE': 1650.2537424634395,
#   'R^2': 0.996239866856085}}

# %%
train_and_test_scores = {'Tuned RF': {'MAE': 26.939573778039026},
                         'RF Training Scores': {'MAE': 26.3487}}
rf_df = pd.DataFrame(train_and_test_scores)
rf_df.T
# Out:
#                           MAE
# Tuned RF            26.939574
# RF Training Scores  26.348700

# %%
comp = rf_df.plot(kind='bar', figsize=(8,6), color=['salmon', 'lightgreen']);
plt.title('Training vs Testing MAE Score Comparison');
plt.xlabel('Model');
plt.ylabel('Mean Absolute Error Score');
diff = rf_scores['Tuned Random Forest']['MAE'] - train_scores['RF Train Scores']['MAE']
print('MAE Difference Between Training and Testing Data = ', diff)
# Out:
# MAE Difference Between Training and Testing Data =  0.590865308473191
